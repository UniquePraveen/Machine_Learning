# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("sample.csv")

# %%
data
# Out:
#     age  job
# 0    16    0
# 1    24    0
# 2    31    1
# 3    29    0
# 4    40    1
# 5    33    0
# 6    18    0
# 7    36    1
# 8    15    0
# 9    37    1
# 10   19    0
# 11   21    0
# 12   29    1
# 13   31    1
# 14   23    1
# 15   20    0
# 16   34    1
# 17   22    0
# 18   32    1
# 19   15    0
# 20   14    0
# 21   13    0
# 22   51    1
# 23   43    1
# 24   23    0
# 25   31    1

# %%
data.head()
# Out:
#    age  job
# 0   16    0
# 1   24    0
# 2   31    1
# 3   29    0
# 4   40    1

# %%
data.tail()
# Out:
#     age  job
# 21   13    0
# 22   51    1
# 23   43    1
# 24   23    0
# 25   31    1

# %%
plt.scatter(data.age,data.job)
plt.xlabel("Age")
plt.ylabel("Job")
# Out:
# Text(0, 0.5, 'Job')

# %%
x = data[["age"]]
x
# Out:
#     age
# 0    16
# 1    24
# 2    31
# 3    29
# 4    40
# 5    33
# 6    18
# 7    36
# 8    15
# 9    37
# 10   19
# 11   21
# 12   29
# 13   31
# 14   23
# 15   20
# 16   34
# 17   22
# 18   32
# 19   15
# 20   14
# 21   13
# 22   51
# 23   43
# 24   23
# 25   31

# %%
y = data["job"]
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     0
# 6     0
# 7     1
# 8     0
# 9     1
# 10    0
# 11    0
# 12    1
# 13    1
# 14    1
# 15    0
# 16    1
# 17    0
# 18    1
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    0
# 25    1
# Name: job, dtype: int64

# %%
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     0
# 6     0
# 7     1
# 8     0
# 9     1
# 10    0
# 11    0
# 12    1
# 13    1
# 14    1
# 15    0
# 16    1
# 17    0
# 18    1
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    0
# 25    1
# Name: job, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=.25)

# %%
x_train
# Out:
#     age
# 23   43
# 7    36
# 16   34
# 12   29
# 25   31
# 14   23
# 3    29
# 4    40
# 13   31
# 5    33
# 1    24
# 6    18
# 10   19
# 24   23
# 9    37
# 0    16
# 22   51
# 8    15
# 2    31

# %%
x_test
# Out:
#     age
# 17   22
# 15   20
# 20   14
# 19   15
# 21   13
# 18   32
# 11   21

# %%
y_test
# Out:
# 17    0
# 15    0
# 20    0
# 19    0
# 21    0
# 18    1
# 11    0
# Name: job, dtype: int64

# %%
y_train
# Out:
# 23    1
# 7     1
# 16    1
# 12    1
# 25    1
# 14    1
# 3     0
# 4     1
# 13    1
# 5     0
# 1     0
# 6     0
# 10    0
# 24    0
# 9     1
# 0     0
# 22    1
# 8     0
# 2     1
# Name: job, dtype: int64

# %%
len(x_train)
# Out:
# 19

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 0, 0, 0, 0, 1, 0])

# %%
y_test
# Out:
# 17    0
# 15    0
# 20    0
# 19    0
# 21    0
# 18    1
# 11    0
# Name: job, dtype: int64

# %%
model.predict(x_test)
# Out:
# array([0, 0, 0, 0, 0, 1, 0])

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
age = [[25]]
model.predict(age)
# Out:
# /Users/praveen/myenv/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
ages = np.array([[25],[26],[27],[28],[29],[30]])
model.predict(ages)
# Out:
# /Users/praveen/myenv/lib/python3.13/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0, 0, 0, 1, 1, 1])
